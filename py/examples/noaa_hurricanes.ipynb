# %% [markdown]
# # Pydeck Earth Engine Introduction
#
# This is an introduction to using [Pydeck](https://pydeck.gl) and [Deck.gl](https://deck.gl) with [Google Earth Engine](https://earthengine.google.com/) in Jupyter Notebooks.

# %% [markdown]
# If you wish to run this locally, you'll need to install some dependencies. Installing into a new Conda environment is recommended. To create and enter the environment, run:
# ```
# conda create -n pydeck-ee -c conda-forge python jupyter notebook pydeck earthengine-api requests -y
# conda activate pydeck-ee
#
# # Install the pydeck-earthengine-layers package from pip
# pip install pydeck-earthengine-layers
#
# jupyter nbextension install --sys-prefix --symlink --overwrite --py pydeck
# jupyter nbextension enable --sys-prefix --py pydeck
# ```
# then open Jupyter Notebook with `jupyter notebook`.

# %% [markdown]
# Now in a Python Jupyter Notebook, let's first import required packages:

# %%
from pydeck_earthengine_layers import EarthEngineLayer
import pydeck as pdk
import ee

# %% [markdown]
# ## Authentication
#
# ### Authenticate with Earth Engine
#
# Using Earth Engine requires authentication. If you don't have a Google account approved for use with Earth Engine, you'll need to request access. For more information and to sign up, go to https://signup.earthengine.google.com/.

# %% [markdown]
# If you haven't used Earth Engine in Python before, you'll need to run the following authentication command. If you've previously authenticated in Python or the command line, you can skip the next line.
#
# Note that this creates a prompt which waits for user input. If you don't see a prompt, you may need to authenticate on the command line with `earthengine authenticate` and then return here, skipping the Python authentication.

# %%
try:
    ee.Initialize()
except Exception as e:
    ee.Authenticate()
    ee.Initialize()

# %% [markdown]
# ### Initialize Earth Engine
#
# The above authentication step creates credentials that are stored on your local computer. Those credentials need to be loaded so that Earth Engine and Pydeck will work.

# %% [markdown]
# ## NOAA Hurricanes example
#
# Now let's make a simple example using Shuttle Radar Topography Mission (SRTM) elevation data. Here we create an `ee.Image` object referencing that dataset.

# %%
# Hurricane tracks and points for 2017.
hurricanes = ee.FeatureCollection('NOAA/NHC/HURDAT2/atlantic')

year = '2017'
points = hurricanes.filter(ee.Filter.date(ee.Date(year).getRange('year')))

# Find all of the hurricane ids.
def get_id(point):
    return ee.Feature(point).get('id')
storm_ids = points.toList(1000).map(get_id).distinct()

# Create a line for each hurricane.
def create_line(storm_id):
    pts = points.filter(ee.Filter.eq('id', ee.String(storm_id)))
    pts = pts.sort('system:time_start')
    line = ee.Geometry.LineString(pts.geometry().coordinates())
    feature = ee.Feature(line)
    return feature.set('id', storm_id)

lines = ee.FeatureCollection(storm_ids.map(create_line))

# %%
def filter_storm_id(storm_id, year='2017'):
    pts = hurricanes.filter(ee.Filter.date(ee.Date(year).getRange('year')))
    pts = pts.filter(ee.Filter.eq('id', ee.String(storm_id)))
    return pts.sort('system:time_start')

# %%
def create_hour(points, property_name='hour_stamp'):
    # Find earliest timestamp
    earliest_timestamp = ee.Number(points.aggregate_min('system:time_start'))
    
    # For each point, subtract this timestamp, then convert from milliseconds to hours
    milli_per_hr = 1000 * 60 * 60
    return points.map(lambda pt: pt.set(property_name, ee.Number(pt.get('system:time_start')).subtract(earliest_timestamp).divide(milli_per_hr)))

# %%
points = filter_storm_id(storm_id)
points = create_hour(points)

# %% [markdown]
# Now we're ready to create the Pydeck layer. The `EarthEngineLayer` makes this simple. Just pass the Earth Engine object to the class.

# %%
lines_layer = EarthEngineLayer(
    lines,
    {'color': 'red'},
    id="tracks",
)

# %%
points_layer = EarthEngineLayer(
    points,
    {'color': 'black'},
    id="points",
)

# %% [markdown]
# Then just pass this layer to a `pydeck.Deck` instance, and call `.show()` to create a map:

# %%
view_state = pdk.ViewState(latitude=36, longitude=-53, zoom=3)
r = pdk.Deck(
    layers=[points_layer, lines_layer], 
    initial_view_state=view_state
)
r.show()

# %% [markdown]
# ## Vector
#
# Let's plot these again, but as a vector dataset, instead of a raster dataset

# %%
lines_layer = EarthEngineLayer(
    lines,
    as_vector=True,
    get_line_color=[255, 0, 0],
    getLineWidth=1000,
    lineWidthMinPixels=3,
    id="tracks",
    library_url="http://0.0.0.0:8003/pydeck_layer_module.min.js"
)
points_layer = EarthEngineLayer(
    points,
    get_fill_color=[0, 0, 0],
    pointRadiusMinPixels=3,
    getRadius=100,
    getLineColor=[255, 255, 255],
    lineWidthMinPixels=0.5,
    as_vector=True,
    stroked=True,
    id="points",
    library_url="http://0.0.0.0:8003/pydeck_layer_module.min.js"
)

# %%
view_state = pdk.ViewState(latitude=36, longitude=-53, zoom=3)
r = pdk.Deck(
    layers=[lines_layer, points_layer], 
    initial_view_state=view_state,
    tooltip=True
)
r.show()
# Out:
# DeckGLWidget(custom_libraries=[{'libraryName': 'EarthEngineLayerLibrary', 'resourceUri': 'http://0.0.0.0:8003/…

# %%
hurricanes.limit(10).getInfo()
# Out:
# {'type': 'FeatureCollection',
#  'columns': {'basin': 'String',
#   'datetime': 'String',
#   'id': 'String',
#   'max_wind_kts': 'Integer',
#   'min_pressure': 'Integer',
#   'name': 'String',
#   'numEntries': 'Integer',
#   'radii_ne_34kt': 'Integer',
#   'radii_ne_50kt': 'Integer',
#   'radii_ne_64kt': 'Integer',
#   'radii_nw_34kt': 'Integer',
#   'radii_nw_50kt': 'Integer',
#   'radii_nw_64kt': 'Integer',
#   'radii_se_34kt': 'Integer',
#   'radii_se_50kt': 'Integer',
#   'radii_se_64kt': 'Integer',
#   'radii_sw_34kt': 'Integer',
#   'radii_sw_50kt': 'Integer',
#   'radii_sw_64kt': 'Integer',
#   'record_id': 'String',
#   'seq': 'Integer',
#   'status': 'String',
#   'system:index': 'String',
#   'system:time_start': 'Long',
#   'year': 'Integer'},
#  'version': 1572361211457807,
#  'id': 'NOAA/NHC/HURDAT2/atlantic',
#  'properties': {'system:asset_size': 2391491},
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-75.19999691921689, 35.30000082489263]},
#    'id': '000000000000000042fc',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-03T18:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 85,
#     'min_pressure': 972,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 90,
#     'radii_ne_50kt': 60,
#     'radii_ne_64kt': 30,
#     'radii_nw_34kt': 50,
#     'radii_nw_50kt': 30,
#     'radii_nw_64kt': 15,
#     'radii_se_34kt': 90,
#     'radii_se_50kt': 50,
#     'radii_se_64kt': 30,
#     'radii_sw_34kt': 75,
#     'radii_sw_50kt': 30,
#     'radii_sw_64kt': 20,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091556000000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-73.69999545674716, 35.99999942646467]},
#    'id': '000000000000000042fd',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-04T00:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 80,
#     'min_pressure': 974,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 80,
#     'radii_ne_50kt': 40,
#     'radii_ne_64kt': 15,
#     'radii_nw_34kt': 50,
#     'radii_nw_50kt': 20,
#     'radii_nw_64kt': 15,
#     'radii_se_34kt': 100,
#     'radii_se_50kt': 50,
#     'radii_se_64kt': 40,
#     'radii_sw_34kt': 75,
#     'radii_sw_50kt': 40,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091577600000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-72.09999865315392, 36.79999782826129]},
#    'id': '000000000000000042fe',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-04T06:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 80,
#     'min_pressure': 973,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 60,
#     'radii_ne_50kt': 40,
#     'radii_ne_64kt': 20,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 15,
#     'radii_se_34kt': 120,
#     'radii_se_50kt': 75,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 75,
#     'radii_sw_50kt': 50,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091599200000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-70.1999979897859, 37.30000128848523]},
#    'id': '000000000000000042ff',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-04T12:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 85,
#     'min_pressure': 973,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 60,
#     'radii_ne_50kt': 40,
#     'radii_ne_64kt': 20,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 15,
#     'radii_se_34kt': 120,
#     'radii_se_50kt': 75,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 75,
#     'radii_sw_50kt': 50,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091620800000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-68.30000178551892, 37.80000028960813]},
#    'id': '00000000000000004300',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-04T18:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 95,
#     'min_pressure': 965,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 90,
#     'radii_ne_50kt': 50,
#     'radii_ne_64kt': 25,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 15,
#     'radii_se_34kt': 150,
#     'radii_se_50kt': 75,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 125,
#     'radii_sw_50kt': 50,
#     'radii_sw_64kt': 25,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091642400000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-66.0000019212526, 38.499998891180155]},
#    'id': '00000000000000004301',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-05T00:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 105,
#     'min_pressure': 957,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 80,
#     'radii_ne_50kt': 50,
#     'radii_ne_64kt': 30,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 20,
#     'radii_se_34kt': 150,
#     'radii_se_50kt': 80,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 125,
#     'radii_sw_50kt': 60,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091664000000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-63.099998796537754, 39.50000135252698]},
#    'id': '00000000000000004302',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-05T06:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 105,
#     'min_pressure': 957,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 80,
#     'radii_ne_50kt': 50,
#     'radii_ne_64kt': 30,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 20,
#     'radii_se_34kt': 225,
#     'radii_se_50kt': 80,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 200,
#     'radii_sw_50kt': 60,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091685600000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-59.599996870475444, 40.79999875544649]},
#    'id': '00000000000000004303',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-05T12:00:00',
#     'id': 'AL012004',
#     'max_wind_kts': 100,
#     'min_pressure': 962,
#     'name': 'ALEX',
#     'numEntries': 25,
#     'radii_ne_34kt': 80,
#     'radii_ne_50kt': 50,
#     'radii_ne_64kt': 30,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 50,
#     'radii_nw_64kt': 20,
#     'radii_se_34kt': 300,
#     'radii_se_50kt': 80,
#     'radii_se_64kt': 50,
#     'radii_sw_34kt': 300,
#     'radii_sw_50kt': 60,
#     'radii_sw_64kt': 30,
#     'record_id': '',
#     'seq': 1,
#     'status': 'HU',
#     'system:time_start': 1091707200000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-76.80000264101221, 16.700002310312826]},
#    'id': '00000000000000004304',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-11T18:00:00',
#     'id': 'AL032004',
#     'max_wind_kts': 65,
#     'min_pressure': 993,
#     'name': 'CHARLEY',
#     'numEntries': 30,
#     'radii_ne_34kt': 90,
#     'radii_ne_50kt': 40,
#     'radii_ne_64kt': 25,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 40,
#     'radii_nw_64kt': 25,
#     'radii_se_34kt': 75,
#     'radii_se_50kt': 0,
#     'radii_se_64kt': 0,
#     'radii_sw_34kt': 0,
#     'radii_sw_50kt': 0,
#     'radii_sw_64kt': 0,
#     'record_id': '',
#     'seq': 3,
#     'status': 'HU',
#     'system:time_start': 1092247200000,
#     'year': 2004}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': [-78.10000004393171, 17.40000091188487]},
#    'id': '00000000000000004305',
#    'properties': {'basin': 'AL',
#     'datetime': '2004-08-12T00:00:00',
#     'id': 'AL032004',
#     'max_wind_kts': 65,
#     'min_pressure': 992,
#     'name': 'CHARLEY',
#     'numEntries': 30,
#     'radii_ne_34kt': 90,
#     'radii_ne_50kt': 40,
#     'radii_ne_64kt': 25,
#     'radii_nw_34kt': 75,
#     'radii_nw_50kt': 40,
#     'radii_nw_64kt': 25,
#     'radii_se_34kt': 75,
#     'radii_se_50kt': 0,
#     'radii_se_64kt': 0,
#     'radii_sw_34kt': 30,
#     'radii_sw_50kt': 0,
#     'radii_sw_64kt': 0,
#     'record_id': '',
#     'seq': 3,
#     'status': 'HU',
#     'system:time_start': 1092268800000,
#     'year': 2004}}]}
